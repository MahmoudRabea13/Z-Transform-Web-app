# %%
import scipy
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt

# %%
from classes.filter import Filter

# %%
filter = Filter()
filter.set_zeros([-0.013010668748373666+0.7311995836586j,0.5594587561800677+0.023419203747072598j,-0.6271142336716107+0.01821493624772313j,0.4085349986989331+0.4449648711943794j,-0.4501691386937288+0.43455633619568046j])
filter.set_poles([0.24720270621909965+0.7051782461618527j,-0.0026021337496747333+0.9029404111371324j,-0.2992453812125943+0.575071558678116j,-0.5802758261774655+0.23679417122040072j,0.5386416861826697+0.2524069737184491j])
frequency, magnitude, phase = filter.get_response()
filter.plot_response(frequency, magnitude, phase)

# %%
filter = Filter()

# %%
filter.set_zeros(-10)
filter.set_poles(-0.1)
frequency, magnitude, phase = filter.get_response()
plt.figure()
plt.title('a=-0.1')
plt.plot(frequency, phase)
plt.xlim(-0.01,np.pi+0.01)
plt.savefig('./static/catalog/-0.1.png')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 4, 1000)
y1 = np.sin(2*np.pi*1*x)
y2 = np.sin(2*np.pi*3*x)
y = y1 + y2

# %%
plt.plot(x, y)

# %%
data = {'x':x, 'y':y}
df = pd.DataFrame(data)
df.to_csv('./static/1+3hz-sine.csv', index=False)

# %%
x = "3+2j"

# %%
x_new = complex(x)

# %%
x_new*(3-2j)
# Out:
# (13+0j)

# %%
new = {'x':[1,2,3,4],'y':[3,4,1,5]}
out = []
for i in range(len(new['x'])):
    out.append(new['x'][i]+new['y'][i]*1j)

# %%
out
# Out:
# [(1+3j), (2+4j), (3+1j), (4+5j)]
